# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('datasets/Achieve.csv')

# %%
data
# Out:
#          row    id  region  corp  school  class  gender  age  race  geread  \
# 0          1     1       2   940     767      1       2  104     5     3.5
# 1          2     2       2   940     767      1       2  106     5     1.2
# 2          3     3       2   940     767      1       2  112     5     2.1
# 3          4     4       2   940     767      1       2  109     5     1.6
# 4          5     5       2   940     767      1       1  107     5     3.7
# 5          6     6       2   940     767      1       1  108     5     2.4
# 6          7     7       2   940     767      1       1  101     5     3.1
# 7          8     8       2   940     767      1       2  103     5     2.9
# 8          9     9       2   940     767      1       1  104     5     4.9
# 9         10    10       2   940     767      1       2  110     5     5.0
# 10        11    11       2   940     767      1       2  110     5     4.9
# ...

# %% [markdown]
# ls datasets
